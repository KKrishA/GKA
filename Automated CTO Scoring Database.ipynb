# %%
import pandas as pd
import os
import numpy as np
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df = pd.read_csv('questions_data.csv')

# %%
df.set_index('Unnamed: 0')
# Out:
#                                                           Unnamed: 1  \
# Unnamed: 0
# Name                                                        Sub Link
# NaN                                                              NaN
# AVERAGE                                                          NaN
# STDEV                                                            NaN
# MAX                                                              NaN
# ...                                                              ...
# Chiderah Okoye     https://www.cleantechopen.org/private.php/en/d...
# Pontsho Moletsane  https://www.cleantechopen.org/private.php/en/d...
# Troy Billett       https://www.cleantechopen.org/private.php/en/d...
# Durham Giles       https://www.cleantechopen.org/private.php/en/d...
# Farshid Roumi      https://www.cleantechopen.org/private.php/en/d...
#
#                                Unnamed: 2    Unnamed: 3  \
# Unnamed: 0
# Name                              Company  Times scored
# NaN                                   NaN           NaN
# AVERAGE                               NaN           NaN
# STDEV                                 NaN           NaN
# MAX                                   NaN           NaN
# ...                                   ...           ...
# Chiderah Okoye          Nordee Enterprise             2
# Pontsho Moletsane                 Nosetsa             2
# Troy Billett               OffGridBox USA             2
# Durham Giles       Ogive Technology, Inc.             2
# Farshid Roumi             Parthian Energy             2
#
#                                Unnamed: 4                     Unnamed: 5  \
# Unnamed: 0
# Name                       Link to scores                       Industry
# NaN                                   NaN                            NaN
# AVERAGE                               NaN                            NaN
# STDEV                                 NaN                            NaN
# MAX                                   NaN                            NaN
# ...                                   ...                            ...
# Chiderah Okoye          Nordee Enterprise  Energy Distribution & Storage
# Pontsho Moletsane                 Nosetsa      Agriculture Water & Waste
# Troy Billett               OffGridBox USA      Agriculture Water & Waste
# Durham Giles       Ogive Technology, Inc.      Agriculture Water & Waste
# Farshid Roumi             Parthian Energy  Energy Distribution & Storage
#
#                   Unnamed: 6     Unnamed: 7 Unnamed: 8 COMPANY SCORING  \
# Unnamed: 0
# Name                    Year         Region      Phase           Score
# NaN                      NaN            NaN        NaN             NaN
# AVERAGE                  NaN            NaN        NaN           40.66
# STDEV                    NaN            NaN        NaN           10.36
# MAX                      NaN            NaN        NaN           65.90
# ...                      ...            ...        ...             ...
# Chiderah Okoye          2021      Northeast    Reg EBD            43.6
# Pontsho Moletsane       2021           West    Reg EBD            35.4
# Troy Billett            2021  South Central    Reg EBD            54.8
# Durham Giles            2021           West    Reg EBD            38.7
# Farshid Roumi           2021           West    Reg EBD            51.9
#
#                           Unnamed: 10  ...  \
# Unnamed: 0                             ...
# Name               1. Business Canvas  ...
# NaN                               NaN  ...
# AVERAGE                          3.01  ...
# STDEV                            0.86  ...
# MAX                              5.10  ...
# ...                               ...  ...
# Chiderah Okoye                    2.7  ...
# Pontsho Moletsane                 3.5  ...
# Troy Billett                      4.6  ...
# Durham Giles                      2.8  ...
# Farshid Roumi                     4.1  ...
#
#                                                 Unnamed: 303  \
# Unnamed: 0
# Name               IP49: Thorough and thoughtful financials?
# NaN                                                      NaN
# AVERAGE                                                 0.38
# STDEV                                                   0.57
# MAX                                                     7.00
# ...                                                      ...
# Chiderah Okoye                                          1.00
# Pontsho Moletsane                                       1.00
# Troy Billett                                            0.00
# Durham Giles                                            0.00
# Farshid Roumi                                           0.00
#
#                                                  Unnamed: 304  \
# Unnamed: 0
# Name               IP50: P&L, Income Statement, Balance Sheet
# NaN                                                       NaN
# AVERAGE                                                  0.25
# STDEV                                                    0.53
# MAX                                                      7.00
# ...                                                       ...
# Chiderah Okoye                                           0.00
# Pontsho Moletsane                                        1.00
# Troy Billett                                             0.50
# Durham Giles                                             0.00
# Farshid Roumi                                            0.00
#
#                                                        Unnamed: 305  \
# Unnamed: 0
# Name               IP51: Provide high level 3 or 5 year projections
# NaN                                                             NaN
# AVERAGE                                                        0.46
# STDEV                                                          0.57
# MAX                                                            5.50
# ...                                                             ...
# Chiderah Okoye                                                 1.00
# Pontsho Moletsane                                              1.00
# Troy Billett                                                   1.00
# Durham Giles                                                   0.00
# Farshid Roumi                                                  0.00
#
#                                                       Unnamed: 306  \
# Unnamed: 0
# Name               IP52: Revenues and expenses by major categories
# NaN                                                            NaN
# AVERAGE                                                       0.32
# STDEV                                                         0.47
# MAX                                                           5.00
# ...                                                            ...
# Chiderah Okoye                                                1.00
# Pontsho Moletsane                                             1.00
# Troy Billett                                                  1.00
# Durham Giles                                                  0.00
# Farshid Roumi                                                 0.00
#
#                                                         Unnamed: 307  \
# Unnamed: 0
# Name               IP53: Pre-tax profit (loss), cash flow, capita...
# NaN                                                              NaN
# AVERAGE                                                         0.22
# STDEV                                                           0.37
# MAX                                                             1.23
# ...                                                              ...
# Chiderah Okoye                                                  0.00
# Pontsho Moletsane                                               1.00
# Troy Billett                                                    1.00
# Durham Giles                                                    0.00
# Farshid Roumi                                                   0.00
#
#                                         Unnamed: 308          Unnamed: 309  \
# Unnamed: 0
# Name               IP54: Highlight milestone targets  IP55: First revenues
# NaN                                              NaN                   NaN
# AVERAGE                                         0.23                  0.24
# STDEV                                           0.41                  0.43
# MAX                                             3.67                  5.00
# ...                                              ...                   ...
# Chiderah Okoye                                  0.00                  0.00
# Pontsho Moletsane                               0.00                  0.00
# Troy Billett                                    1.00                  0.50
# Durham Giles                                    1.00                  0.00
# Farshid Roumi                                   0.00                  0.00
#
#                                Unnamed: 310  \
# Unnamed: 0
# Name               IP56: Cash-flow positive
# NaN                                     NaN
# AVERAGE                                0.21
# STDEV                                  0.54
# MAX                                    9.18
# ...                                     ...
# Chiderah Okoye                         0.00
# Pontsho Moletsane                      0.00
# Troy Billett                           0.00
# Durham Giles                           0.00
# Farshid Roumi                          0.00
#
#                                                         Unnamed: 311  \
# Unnamed: 0
# Name               IP57: Tangible competitive barriers (customers...
# NaN                                                              NaN
# AVERAGE                                                         0.13
# STDEV                                                           0.29
# MAX                                                             1.00
# ...                                                              ...
# Chiderah Okoye                                                  0.00
# Pontsho Moletsane                                               1.00
# Troy Billett                                                    1.00
# Durham Giles                                                    1.00
# Farshid Roumi                                                   0.50
#
#                                                         Unnamed: 312
# Unnamed: 0
# Name               IP58: $100M/yr run rate in year 5 is cliché, b...
# NaN                                                              NaN
# AVERAGE                                                         0.05
# STDEV                                                           0.19
# MAX                                                             1.14
# ...                                                              ...
# Chiderah Okoye                                                  0.00
# Pontsho Moletsane                                               0.00
# Troy Billett                                                    0.00
# Durham Giles                                                    0.00
# Farshid Roumi                                                   0.00
#
# [500 rows x 312 columns]

# %%
df = df.rename(index={'Unnamed: 0': 'Name'})

# %%
df.columns = df.iloc[0]
df = df[1:]
df.index = df.iloc[:, 0]
df = df.iloc[:, 1:]

# %%
print(df.columns)
df
# Out:
# Index(['Sub Link', 'Company', 'Times scored', 'Link to scores', 'Industry',
#        'Year', 'Region', 'Phase', 'Score', '1. Business Canvas',
#        ...
#        'IP49: Thorough and thoughtful financials?',
#        'IP50: P&L, Income Statement, Balance Sheet',
#        'IP51: Provide high level 3 or 5 year projections',
#        'IP52: Revenues and expenses by major categories',
#        'IP53: Pre-tax profit (loss), cash flow, capital requirements, headcount',
#        'IP54: Highlight milestone targets', 'IP55: First revenues',
#        'IP56: Cash-flow positive',
#        'IP57: Tangible competitive barriers (customers, IP, etc.)',
#        'IP58: $100M/yr run rate in year 5 is cliché, but expected'],
#       dtype='object', name=0, length=312)
# 0                                                           Sub Link  \
# Name
# NaN                                                              NaN
# AVERAGE                                                          NaN
# STDEV                                                            NaN
# MAX                                                              NaN
# NaN                                                              NaN
# ...                                                              ...
# Chiderah Okoye     https://www.cleantechopen.org/private.php/en/d...
# Pontsho Moletsane  https://www.cleantechopen.org/private.php/en/d...
# Troy Billett       https://www.cleantechopen.org/private.php/en/d...
# Durham Giles       https://www.cleantechopen.org/private.php/en/d...
# Farshid Roumi      https://www.cleantechopen.org/private.php/en/d...
#
# 0                                 Company Times scored  \
# Name
# NaN                                   NaN          NaN
# AVERAGE                               NaN          NaN
# STDEV                                 NaN          NaN
# MAX                                   NaN          NaN
# NaN                                   NaN          NaN
# ...                                   ...          ...
# Chiderah Okoye          Nordee Enterprise            2
# Pontsho Moletsane                 Nosetsa            2
# Troy Billett               OffGridBox USA            2
# Durham Giles       Ogive Technology, Inc.            2
# Farshid Roumi             Parthian Energy            2
#
# 0                          Link to scores                       Industry  \
# Name
# NaN                                   NaN                            NaN
# AVERAGE                               NaN                            NaN
# STDEV                                 NaN                            NaN
# MAX                                   NaN                            NaN
# NaN                                   NaN                            NaN
# ...                                   ...                            ...
# Chiderah Okoye          Nordee Enterprise  Energy Distribution & Storage
# Pontsho Moletsane                 Nosetsa      Agriculture Water & Waste
# Troy Billett               OffGridBox USA      Agriculture Water & Waste
# Durham Giles       Ogive Technology, Inc.      Agriculture Water & Waste
# Farshid Roumi             Parthian Energy  Energy Distribution & Storage
#
# 0                  Year         Region    Phase  Score 1. Business Canvas  \
# Name
# NaN                 NaN            NaN      NaN    NaN                NaN
# AVERAGE             NaN            NaN      NaN  40.66               3.01
# STDEV               NaN            NaN      NaN  10.36               0.86
# MAX                 NaN            NaN      NaN  65.90               5.10
# NaN                 NaN            NaN      NaN    NaN                NaN
# ...                 ...            ...      ...    ...                ...
# Chiderah Okoye     2021      Northeast  Reg EBD   43.6                2.7
# Pontsho Moletsane  2021           West  Reg EBD   35.4                3.5
# Troy Billett       2021  South Central  Reg EBD   54.8                4.6
# Durham Giles       2021           West  Reg EBD   38.7                2.8
# Farshid Roumi      2021           West  Reg EBD   51.9                4.1
#
# 0                  ... IP49: Thorough and thoughtful financials?  \
# Name               ...
# NaN                ...                                       NaN
# AVERAGE            ...                                      0.38
# STDEV              ...                                      0.57
# MAX                ...                                      7.00
# NaN                ...                                       NaN
# ...                ...                                       ...
# Chiderah Okoye     ...                                      1.00
# Pontsho Moletsane  ...                                      1.00
# Troy Billett       ...                                      0.00
# Durham Giles       ...                                      0.00
# Farshid Roumi      ...                                      0.00
#
# 0                 IP50: P&L, Income Statement, Balance Sheet  \
# Name
# NaN                                                      NaN
# AVERAGE                                                 0.25
# STDEV                                                   0.53
# MAX                                                     7.00
# NaN                                                      NaN
# ...                                                      ...
# Chiderah Okoye                                          0.00
# Pontsho Moletsane                                       1.00
# Troy Billett                                            0.50
# Durham Giles                                            0.00
# Farshid Roumi                                           0.00
#
# 0                 IP51: Provide high level 3 or 5 year projections  \
# Name
# NaN                                                            NaN
# AVERAGE                                                       0.46
# STDEV                                                         0.57
# MAX                                                           5.50
# NaN                                                            NaN
# ...                                                            ...
# Chiderah Okoye                                                1.00
# Pontsho Moletsane                                             1.00
# Troy Billett                                                  1.00
# Durham Giles                                                  0.00
# Farshid Roumi                                                 0.00
#
# 0                 IP52: Revenues and expenses by major categories  \
# Name
# NaN                                                           NaN
# AVERAGE                                                      0.32
# STDEV                                                        0.47
# MAX                                                          5.00
# NaN                                                           NaN
# ...                                                           ...
# Chiderah Okoye                                               1.00
# Pontsho Moletsane                                            1.00
# Troy Billett                                                 1.00
# Durham Giles                                                 0.00
# Farshid Roumi                                                0.00
#
# 0                 IP53: Pre-tax profit (loss), cash flow, capital requirements, headcount  \
# Name
# NaN                                                              NaN
# AVERAGE                                                         0.22
# STDEV                                                           0.37
# MAX                                                             1.23
# NaN                                                              NaN
# ...                                                              ...
# Chiderah Okoye                                                  0.00
# Pontsho Moletsane                                               1.00
# Troy Billett                                                    1.00
# Durham Giles                                                    0.00
# Farshid Roumi                                                   0.00
#
# 0                 IP54: Highlight milestone targets IP55: First revenues  \
# Name
# NaN                                             NaN                  NaN
# AVERAGE                                        0.23                 0.24
# STDEV                                          0.41                 0.43
# MAX                                            3.67                 5.00
# NaN                                             NaN                  NaN
# ...                                             ...                  ...
# Chiderah Okoye                                 0.00                 0.00
# Pontsho Moletsane                              0.00                 0.00
# Troy Billett                                   1.00                 0.50
# Durham Giles                                   1.00                 0.00
# Farshid Roumi                                  0.00                 0.00
#
# 0                 IP56: Cash-flow positive  \
# Name
# NaN                                    NaN
# AVERAGE                               0.21
# STDEV                                 0.54
# MAX                                   9.18
# NaN                                    NaN
# ...                                    ...
# Chiderah Okoye                        0.00
# Pontsho Moletsane                     0.00
# Troy Billett                          0.00
# Durham Giles                          0.00
# Farshid Roumi                         0.00
#
# 0                 IP57: Tangible competitive barriers (customers, IP, etc.)  \
# Name
# NaN                                                              NaN
# AVERAGE                                                         0.13
# STDEV                                                           0.29
# MAX                                                             1.00
# NaN                                                              NaN
# ...                                                              ...
# Chiderah Okoye                                                  0.00
# Pontsho Moletsane                                               1.00
# Troy Billett                                                    1.00
# Durham Giles                                                    1.00
# Farshid Roumi                                                   0.50
#
# 0                 IP58: $100M/yr run rate in year 5 is cliché, but expected
# Name
# NaN                                                              NaN
# AVERAGE                                                         0.05
# STDEV                                                           0.19
# MAX                                                             1.14
# NaN                                                              NaN
# ...                                                              ...
# Chiderah Okoye                                                  0.00
# Pontsho Moletsane                                               0.00
# Troy Billett                                                    0.00
# Durham Giles                                                    0.00
# Farshid Roumi                                                   0.00
#
# [499 rows x 312 columns]

# %%
df = df.drop(df.index[0])

# %%
df
# Out:
# 0                                                            Sub Link  \
# Name
# AVERAGE                                                           NaN
# STDEV                                                             NaN
# MAX                                                               NaN
# 3rd Gen Renewables  https://www.cleantechopen.org/private.php/en/d...
# AlterVia            https://www.cleantechopen.org/private.php/en/d...
# ...                                                               ...
# Chiderah Okoye      https://www.cleantechopen.org/private.php/en/d...
# Pontsho Moletsane   https://www.cleantechopen.org/private.php/en/d...
# Troy Billett        https://www.cleantechopen.org/private.php/en/d...
# Durham Giles        https://www.cleantechopen.org/private.php/en/d...
# Farshid Roumi       https://www.cleantechopen.org/private.php/en/d...
#
# 0                                  Company Times scored  \
# Name
# AVERAGE                                NaN          NaN
# STDEV                                  NaN          NaN
# MAX                                    NaN          NaN
# 3rd Gen Renewables      3rd Gen Renewables            3
# AlterVia                          AlterVia            3
# ...                                    ...          ...
# Chiderah Okoye           Nordee Enterprise            2
# Pontsho Moletsane                  Nosetsa            2
# Troy Billett                OffGridBox USA            2
# Durham Giles        Ogive Technology, Inc.            2
# Farshid Roumi              Parthian Energy            2
#
# 0                           Link to scores                       Industry  \
# Name
# AVERAGE                                NaN                            NaN
# STDEV                                  NaN                            NaN
# MAX                                    NaN                            NaN
# 3rd Gen Renewables      3rd gen renewables              Energy Generation
# AlterVia                          AlterVia              Energy Generation
# ...                                    ...                            ...
# Chiderah Okoye           Nordee Enterprise  Energy Distribution & Storage
# Pontsho Moletsane                  Nosetsa      Agriculture Water & Waste
# Troy Billett                OffGridBox USA      Agriculture Water & Waste
# Durham Giles        Ogive Technology, Inc.      Agriculture Water & Waste
# Farshid Roumi              Parthian Energy  Energy Distribution & Storage
#
# 0                   Year         Region        Phase  Score  \
# Name
# AVERAGE              NaN            NaN          NaN  40.66
# STDEV                NaN            NaN          NaN  10.36
# MAX                  NaN            NaN          NaN  65.90
# 3rd Gen Renewables  2018           West  First Round   19.5
# AlterVia            2018           West  First Round   20.3
# ...                  ...            ...          ...    ...
# Chiderah Okoye      2021      Northeast      Reg EBD   43.6
# Pontsho Moletsane   2021           West      Reg EBD   35.4
# Troy Billett        2021  South Central      Reg EBD   54.8
# Durham Giles        2021           West      Reg EBD   38.7
# Farshid Roumi       2021           West      Reg EBD   51.9
#
# 0                  1. Business Canvas  ...  \
# Name                                   ...
# AVERAGE                          3.01  ...
# STDEV                            0.86  ...
# MAX                              5.10  ...
# 3rd Gen Renewables                2.4  ...
# AlterVia                          1.6  ...
# ...                               ...  ...
# Chiderah Okoye                    2.7  ...
# Pontsho Moletsane                 3.5  ...
# Troy Billett                      4.6  ...
# Durham Giles                      2.8  ...
# Farshid Roumi                     4.1  ...
#
# 0                  IP49: Thorough and thoughtful financials?  \
# Name
# AVERAGE                                                 0.38
# STDEV                                                   0.57
# MAX                                                     7.00
# 3rd Gen Renewables                                      0.00
# AlterVia                                                0.00
# ...                                                      ...
# Chiderah Okoye                                          1.00
# Pontsho Moletsane                                       1.00
# Troy Billett                                            0.00
# Durham Giles                                            0.00
# Farshid Roumi                                           0.00
#
# 0                  IP50: P&L, Income Statement, Balance Sheet  \
# Name
# AVERAGE                                                  0.25
# STDEV                                                    0.53
# MAX                                                      7.00
# 3rd Gen Renewables                                       0.00
# AlterVia                                                 0.00
# ...                                                       ...
# Chiderah Okoye                                           0.00
# Pontsho Moletsane                                        1.00
# Troy Billett                                             0.50
# Durham Giles                                             0.00
# Farshid Roumi                                            0.00
#
# 0                  IP51: Provide high level 3 or 5 year projections  \
# Name
# AVERAGE                                                        0.46
# STDEV                                                          0.57
# MAX                                                            5.50
# 3rd Gen Renewables                                              NaN
# AlterVia                                                        NaN
# ...                                                             ...
# Chiderah Okoye                                                 1.00
# Pontsho Moletsane                                              1.00
# Troy Billett                                                   1.00
# Durham Giles                                                   0.00
# Farshid Roumi                                                  0.00
#
# 0                  IP52: Revenues and expenses by major categories  \
# Name
# AVERAGE                                                       0.32
# STDEV                                                         0.47
# MAX                                                           5.00
# 3rd Gen Renewables                                             NaN
# AlterVia                                                       NaN
# ...                                                            ...
# Chiderah Okoye                                                1.00
# Pontsho Moletsane                                             1.00
# Troy Billett                                                  1.00
# Durham Giles                                                  0.00
# Farshid Roumi                                                 0.00
#
# 0                  IP53: Pre-tax profit (loss), cash flow, capital requirements, headcount  \
# Name
# AVERAGE                                                          0.22
# STDEV                                                            0.37
# MAX                                                              1.23
# 3rd Gen Renewables                                                NaN
# AlterVia                                                          NaN
# ...                                                               ...
# Chiderah Okoye                                                   0.00
# Pontsho Moletsane                                                1.00
# Troy Billett                                                     1.00
# Durham Giles                                                     0.00
# Farshid Roumi                                                    0.00
#
# 0                  IP54: Highlight milestone targets IP55: First revenues  \
# Name
# AVERAGE                                         0.23                 0.24
# STDEV                                           0.41                 0.43
# MAX                                             3.67                 5.00
# 3rd Gen Renewables                               NaN                  NaN
# AlterVia                                         NaN                  NaN
# ...                                              ...                  ...
# Chiderah Okoye                                  0.00                 0.00
# Pontsho Moletsane                               0.00                 0.00
# Troy Billett                                    1.00                 0.50
# Durham Giles                                    1.00                 0.00
# Farshid Roumi                                   0.00                 0.00
#
# 0                  IP56: Cash-flow positive  \
# Name
# AVERAGE                                0.21
# STDEV                                  0.54
# MAX                                    9.18
# 3rd Gen Renewables                      NaN
# AlterVia                                NaN
# ...                                     ...
# Chiderah Okoye                         0.00
# Pontsho Moletsane                      0.00
# Troy Billett                           0.00
# Durham Giles                           0.00
# Farshid Roumi                          0.00
#
# 0                  IP57: Tangible competitive barriers (customers, IP, etc.)  \
# Name
# AVERAGE                                                          0.13
# STDEV                                                            0.29
# MAX                                                              1.00
# 3rd Gen Renewables                                                NaN
# AlterVia                                                          NaN
# ...                                                               ...
# Chiderah Okoye                                                   0.00
# Pontsho Moletsane                                                1.00
# Troy Billett                                                     1.00
# Durham Giles                                                     1.00
# Farshid Roumi                                                    0.50
#
# 0                  IP58: $100M/yr run rate in year 5 is cliché, but expected
# Name
# AVERAGE                                                          0.05
# STDEV                                                            0.19
# MAX                                                              1.14
# 3rd Gen Renewables                                                NaN
# AlterVia                                                          NaN
# ...                                                               ...
# Chiderah Okoye                                                   0.00
# Pontsho Moletsane                                                0.00
# Troy Billett                                                     0.00
# Durham Giles                                                     0.00
# Farshid Roumi                                                    0.00
#
# [497 rows x 312 columns]

# %%
raw = pd.read_csv('2018_2019_raw_data.csv')

# %%
raw.shape
# Out:
# (429, 1446)

# %%
ref = pd.read_csv('reference_df.csv')

# %%
ref
# Out:
# Empty DataFrame
# Columns: [Name, Sub Link, Company, Times scored, Link to scores, Industry, Year, Region, Phase, Score, Incomplete scores, 1. Business Canvas , 2. Impact, 3. Product/ Market Fit , 4. Markets , 5. Tech/ Product, 6. Financials, 7. Legal , 8. Team , 9. Executive Summary , 10. Investor Pitch , BC Scorer 1, BC Scorer 1 Q1, BC Scorer Q2, BC Scorer Q3, BC Scorer Q4, BC Scorer Q5, BC Scorer 2, BC Scorer 2 Q1, BC Scorer 2 Q2, BC Scorer 2 Q3, BC Scorer 2 Q4, BC Scorer 2 Q5, BC Scorer 3, BC Scorer 3 Q1, BC Scorer 3 Q2, BC Scorer 3 Q3, BC Scorer 3 Q4, BC Scorer 3 Q5, BC Scorer 4, BC Scorer 4 Q1, BC Scorer 4 Q2, BC Scorer 4 Q3, BC Scorer 4 Q4, BC Scorer 4 Q5, BC Scorer 5, BC Scorer 5 Q1, BC Scorer 5 Q2, BC Scorer 5 Q3, BC Scorer 5 Q4, BC Scorer 5 Q5, IS Scorer 1, IS Scorer 1 Q1, IS Scorer 1 Q2, IS Scorer 1 Q3, IS Scorer 1 Q4, IS Scorer 1 Q5, IS Scorer 1 Q6, IS Scorer 1 Q7, IS Scorer 1 Q8, IS Scorer 1 Q9, IS Scorer 1 Q10, IS Scorer 2, IS Scorer 2 Q1, IS Scorer 2 Q2, IS Scorer 2 Q3, IS Scorer 2 Q4, IS Scorer 2 Q5, IS Scorer 2 Q6, IS Scorer 2 Q7, IS Scorer 2 Q8, IS Scorer 2 Q9, IS Scorer 2 Q10, IS Scorer 3, IS Scorer 3 Q1, IS Scorer 3 Q2, IS Scorer 3 Q3, IS Scorer 3 Q4, IS Scorer 3 Q5, IS Scorer 3 Q6, IS Scorer 3 Q7, IS Scorer 3 Q8, IS Scorer 3 Q9, IS Scorer 3 Q10, IS Scorer 4, IS Scorer 4 Q1, IS Scorer 4 Q2, IS Scorer 4 Q3, IS Scorer 4 Q4, IS Scorer 4 Q5, IS Scorer 4 Q6, IS Scorer 4 Q7, IS Scorer 4 Q8, IS Scorer 4 Q9, IS Scorer 4 Q10, IS Scorer 5, IS Scorer 5 Q1, IS Scorer 5 Q2, IS Scorer 5 Q3, IS Scorer 5 Q4, ...]
# Index: []
#
# [0 rows x 1446 columns]

# %%
df.columns
# Out:
# Index(['Sub Link', 'Company', 'Times scored', 'Link to scores', 'Industry',
#        'Year', 'Region', 'Phase', 'Score', '1. Business Canvas',
#        ...
#        'IP49: Thorough and thoughtful financials?',
#        'IP50: P&L, Income Statement, Balance Sheet',
#        'IP51: Provide high level 3 or 5 year projections',
#        'IP52: Revenues and expenses by major categories',
#        'IP53: Pre-tax profit (loss), cash flow, capital requirements, headcount',
#        'IP54: Highlight milestone targets', 'IP55: First revenues',
#        'IP56: Cash-flow positive',
#        'IP57: Tangible competitive barriers (customers, IP, etc.)',
#        'IP58: $100M/yr run rate in year 5 is cliché, but expected'],
#       dtype='object', name=0, length=312)

# %%
pd.set_option('display.max_columns', None)

# %%
df.columns
# Out:
# Index(['Sub Link', 'Company', 'Times scored', 'Link to scores', 'Industry',
#        'Year', 'Region', 'Phase', 'Score', '1. Business Canvas',
#        ...
#        'IP49: Thorough and thoughtful financials?',
#        'IP50: P&L, Income Statement, Balance Sheet',
#        'IP51: Provide high level 3 or 5 year projections',
#        'IP52: Revenues and expenses by major categories',
#        'IP53: Pre-tax profit (loss), cash flow, capital requirements, headcount',
#        'IP54: Highlight milestone targets', 'IP55: First revenues',
#        'IP56: Cash-flow positive',
#        'IP57: Tangible competitive barriers (customers, IP, etc.)',
#        'IP58: $100M/yr run rate in year 5 is cliché, but expected'],
#       dtype='object', name=0, length=312)

# %%
df.columns[:100]
# Out:
# Index(['Sub Link', 'Company', 'Times scored', 'Link to scores', 'Industry',
#        'Year', 'Region', 'Phase', 'Score', '1. Business Canvas', '2. Impact',
#        '3. Product/ Market Fit', '4. Markets', '5. Tech/ Product',
#        '6. Financials', '7. Legal', '8. Team', '9. Executive Summary',
#        '10. Investor Pitch', 'Business Canvas',
#        'BCQ1: How clearly is the value propositions understood? ',
#        'BCQ2: Do you know what segments/attributes your customers are?',
#        'BCQ3: Have you interviewed at least 5 customers? ',
#        'BCQ4: Large brackets of the BMC clearly filled and articulated?',
#        'BCQ5: Small brackets of the BMC clearly filled and articulated?',
#        'Impact Statement',
#        'ISQ1: Company purpose directly addresses two or more of the United Nations’ Sustainable Development Goals (SDGs) — maximizing environmental, economic, and social value.',
#        'ISQ2: Clearly defined mapping of applicable SDGs against the company’s value chain',
#        'ISQ3: Addresses if the impact priority is climate mitigation, or climate resilience + adaptation',
#        'ISQ4: Clearly addresses how the startup is better than conventional companies in their sector by some quantifiable number',
#        'ISQ5: Company culture/ What will the company do with profits',
#        'ISQ6: Is Company certified by any environmental organizations?',
#        'ISQ7: What, if any, are existing regulations (local, state, federal, international) that have a direct impact on your license to operate? (If no applicable regulations exist, give one point for this question)',
#        'ISQ8: What, if any, are the environmental or social risks of the materials in your product/service? (e.g. toxicity, availability, recyclability, etc.) (If not applicable, give one point for this question because not a business risk)',
#        'ISQ9: What are your largest sources of energy and land use?',
#        'ISQ10: Please categorize your waste stream by percentage. ',
#        'Product-Market Fit',
#        'PMFQ1: Startup has determined a specific target market and has articulated why they are a better option than other segments',
#        'PMFQ2: Start up has identified a need the target market has that the product fills.',
#        'PMFQ3: Start up has had face to face research-focused discussions with at least 4 members of their target audience.',
#        'PMFQ4: Start up has had face to face research-focused discussions with at least 6 members of their target audience.',
#        'PMFQ5: Start up has had face to face research-focused discussions with 10 or more members of their target audience.',
#        'PMFQ6: start up updated or created customer segments based on research',
#        'PMFQ7: start up updated or created customer archetypes/personas based on research',
#        'PMFQ8: start up updated or changed their user experience based on research',
#        'PMFQ9: based on research, did the start up clearly articulate ANYTHING they learned that changed some aspect of their strategy or product experience?',
#        'PMFQ10: Did the startup create multiple customer segments based on demographic factors (ex: age, income, etc)',
#        'PMFQ11: Did the startup create multiple customer segments based on psychological factors (ex: comfort with technology, attitudes towards cost)',
#        'PMFQ12: Did the startup identify important psychographic attributes associated with their target audience? (ex. Our target audience tends to be skeptical about tech companies)',
#        'PMFQ13: Has the startup validated the size and representativeness of their target market psychographic segmentation through a statistically significant quantitative methodology?',
#        'PMFQ14: Startup has a research-validated range potential customers would be willing to pay for their product or service.',
#        'PMFQ15: Start up has implemented feedback mechanisms into their service or product experience to gather ongoing feedback from individuals who are using or who will use their product/service.',
#        'PMFQ16: Startups has embedded Net Promoter Score (NPS) into ongoing feedback.',
#        'PMFQ17: Has the startup articulated all of the stakeholders in the market they are addressing?',
#        'PMFQ18: Has the start up identified and addressed the needs of all key stakeholders?',
#        'PMFQ19: Have they identified who the purchasing decision-makers in the system are?',
#        'PMFQ20: Startup has someone dedicated to tech tools and ops.',
#        'PMFQ21: Startup has dedicated resources, or individual on team, to user experience.',
#        'PMFQ22: Startup has worked with a user/customer research professional.',
#        'PMFQ23: Startup has a logo that is discernible when smaller than ½ an inch.',
#        'PMFQ24: Startup has a logo that is discernible when billboard size.',
#        'PMFQ25: Startup has a logo that is discernible in greyscale',
#        'PMFQ26: Startup has a cohesive visual design system that is consistent across, e.g., email, website, and other assets.',
#        'PMFQ27: Startup has a branding professional, or has worked with one.',
#        'PMFQ28: Startup has a brand strategy based in customer insights.',
#        'PMFQ29: Has the startup completed a competitive analysis?',
#        'PMFQ30: Has the startup analyzed the reasons why customers use the competition?',
#        'PMFQ31: Has the startup identified unique value that it can deliver to customers?',
#        'PMFQ32: Has the startup identified customer experience pain-points in at least 1 major competitor's product?',
#        'PMFQ33: Has the startup identified customer experience pain-points in at least 3 major competitor's product?',
#        'PMFQ34: Has the startup validated customer experience pain-points through user research?',
#        'Markets',
#        'MQ1: Has the startup identified the channels that its key customers frequently consume media, products, and services via? (eg. Facebook marketplace, Best Buy physical locations, word of mouth)',
#        'MQ2: Does the startup have a clear operational plan to distribute its product or service via distribution channels that customers frequently use?',
#        'MQ3: Has the startup identified ways to leverage their advocates, customers or community to spread their product or service?',
#        'MQ4: Has the startup designed a viral marketing campaign for their product or service targeted at a specific audience?',
#        'MQ5: Has the startup created engagement mechanisms to allow for different levels of user participation?',
#        'MQ6: Has the startup generated a clear strategy to on-board new users?',
#        'MQ7: Has startup identified key barriers to customer purchases?',
#        'MQ8: Has the startup identified sales tactics to address key purchasing barriers?',
#        'MQ9: Has the startup created a customer feedback channel within the sales process?',
#        'MQ10: Has the the startup identified and prioritized the most important features to their customers for GTM rollout?',
#        'MQ11: Has the startup created a product or service roadmap, detailing when features will roll out, and why?',
#        'MQ12: Has the startup clearly identified that they've anticipated the need to gather feedback and pivot in the future?',
#        'Tech and Product',
#        'TP1: Can you cite peer reviewed articles about your core technology?',
#        'TP2: Have you tested the technology internally?',
#        'TP3: Do you have 3rd party validation?',
#        'TP4: Are there other companies using your core technology?',
#        'TP5: How many patents have you filed (including subsequently granted)?',
#        'TP6: How many granted patents do you have?',
#        'TP7: What is your product’s DOD/DOE/Isles Utilities (used by water agencies to vet new technologies intended for use by water agencies and a requirement for consideration- LB) Technology Readiness Level?',
#        'TP8: Do you have an initial prototype?',
#        'TP9: Do you have a full scale prototype or software beta version?',
#        'TP10: Have you identified your 3rd party validation entity (university, national lab, independent test organization, etc.)?',
#        'TP11: Do you have documentation for the cost of 3rd party validation (anticipated or paid)?',
#        'TP12: What stage is the validation?',
#        'TP13: Do you have any field installations with potential customers?',
#        'TP14: Do you have any paid field installations?',
#        'TP15: Does your product need certification (UL, ASTM, etc.)? Score +1 if certification not needed or already obtained, +0.5 if having at least a written plan to complete it, zero if no certification or written plan'],
#       dtype='object', name=0)
